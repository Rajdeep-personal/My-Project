# %% [markdown]
# ## Predicting Sales Price of Used car using Regression

# %% [markdown]
# ## Business Problem: As per the reports from Auto Car India, in FY2021, the pre-owned sector in India stood at 3.8 million units, making it 1.5 times bigger than the 2.6 million unit new car market. While sales in both segments are set to rise in the next few years, the gap is expected to widen, with the research report projecting 8.2 million used car sales in FY2025, compared to 3.9 million new vehicle purchases in the same year.

# %% [markdown]
# # Importing required modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
car = pd.read_csv('Car_details_v3.csv', index_col=[0])

# %%
car
# Out:
#                               year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire VDI        2014         450000     145500  Diesel
# Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# Honda City 2017-2020 EXi      2006         158000     140000  Petrol
# Hyundai i20 Sportz Diesel     2010         225000     127000  Diesel
# Maruti Swift VXI BSIII        2007         130000     120000  Petrol
# ...                            ...            ...        ...     ...
# Hyundai i20 Magna             2013         320000     110000  Petrol
# Hyundai Verna CRDi SX         2007         135000     119000  Diesel
# Maruti Swift Dzire ZDi        2009         382000     120000  Diesel
# Tata Indigo CR4               2013         290000      25000  Diesel
# Tata Indigo CR4               2013         290000      25000  Diesel
#
#                              seller_type transmission                 owner  \
# name
# Maruti Swift Dzire VDI        Individual       Manual           First Owner
# Skoda Rapid 1.5 TDI Ambition  Individual       Manual          Second Owner
# Honda City 2017-2020 EXi      Individual       Manual           Third Owner
# Hyundai i20 Sportz Diesel     Individual       Manual           First Owner
# Maruti Swift VXI BSIII        Individual       Manual           First Owner
# ...                                  ...          ...                   ...
# Hyundai i20 Magna             Individual       Manual           First Owner
# Hyundai Verna CRDi SX         Individual       Manual  Fourth & Above Owner
# Maruti Swift Dzire ZDi        Individual       Manual           First Owner
# Tata Indigo CR4               Individual       Manual           First Owner
# Tata Indigo CR4               Individual       Manual           First Owner
#
#                                  mileage   engine   max_power  \
# name
# Maruti Swift Dzire VDI         23.4 kmpl  1248 CC      74 bhp
# Skoda Rapid 1.5 TDI Ambition  21.14 kmpl  1498 CC  103.52 bhp
# Honda City 2017-2020 EXi       17.7 kmpl  1497 CC      78 bhp
# Hyundai i20 Sportz Diesel      23.0 kmpl  1396 CC      90 bhp
# Maruti Swift VXI BSIII         16.1 kmpl  1298 CC    88.2 bhp
# ...                                  ...      ...         ...
# Hyundai i20 Magna              18.5 kmpl  1197 CC   82.85 bhp
# Hyundai Verna CRDi SX          16.8 kmpl  1493 CC     110 bhp
# Maruti Swift Dzire ZDi         19.3 kmpl  1248 CC    73.9 bhp
# Tata Indigo CR4               23.57 kmpl  1396 CC      70 bhp
# Tata Indigo CR4               23.57 kmpl  1396 CC      70 bhp
#
#                                                  torque  seats
# name
# Maruti Swift Dzire VDI                   190Nm@ 2000rpm    5.0
# Skoda Rapid 1.5 TDI Ambition        250Nm@ 1500-2500rpm    5.0
# Honda City 2017-2020 EXi          12.7@ 2,700(kgm@ rpm)    5.0
# Hyundai i20 Sportz Diesel      22.4 kgm at 1750-2750rpm    5.0
# Maruti Swift VXI BSIII            11.5@ 4,500(kgm@ rpm)    5.0
# ...                                                 ...    ...
# Hyundai i20 Magna                      113.7Nm@ 4000rpm    5.0
# Hyundai Verna CRDi SX         24@ 1,900-2,750(kgm@ rpm)    5.0
# Maruti Swift Dzire ZDi                   190Nm@ 2000rpm    5.0
# Tata Indigo CR4                     140Nm@ 1800-3000rpm    5.0
# Tata Indigo CR4                     140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 12 columns]

# %%
car.shape
# Out:
# (8128, 12)

# %% [markdown]
# # Checking informations

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8128 entries, Maruti Swift Dzire VDI to Tata Indigo CR4
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8128 non-null   int64
#  1   selling_price  8128 non-null   int64
#  2   km_driven      8128 non-null   int64
#  3   fuel           8128 non-null   object
#  4   seller_type    8128 non-null   object
#  5   transmission   8128 non-null   object
#  6   owner          8128 non-null   object
#  7   mileage        7907 non-null   object
#  8   engine         7907 non-null   object
#  9   max_power      7913 non-null   object
#  10  torque         7906 non-null   object
#  11  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 825.5+ KB

# %% [markdown]
# ## There are null values in the attribute 'mileage', 'engine', 'max power', 'torque' , 'seats'

# %%
car.isnull().any()
# Out:
# year             False
# selling_price    False
# km_driven        False
# fuel             False
# seller_type      False
# transmission     False
# owner            False
# mileage           True
# engine            True
# max_power         True
# torque            True
# seats             True
# dtype: bool

# %%
car.isnull().sum()
# Out:
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %% [markdown]
# ## percentage of missing values w.r.t the dataframe car_details

# %%
car.isnull().sum()/len(car) *100
# Out:
# year             0.000000
# selling_price    0.000000
# km_driven        0.000000
# fuel             0.000000
# seller_type      0.000000
# transmission     0.000000
# owner            0.000000
# mileage          2.718996
# engine           2.718996
# max_power        2.645177
# torque           2.731299
# seats            2.718996
# dtype: float64

# %% [markdown]
# ### Insight from the missing values of the attributes:
# #### 1) The percentage of missing values of the attributes is maximum 2-3%(approx) of the whole dataframe. So we can drop those instances for handling these missing values
# #### 2) We can also apply other null imputation methods to fill up the null spaces of the respective attributes.
# #### For this dataframe we are choosing the first method i.e. dropping the instances.

# %% [markdown]
# # Making a copy of the main dataset for processing and other analysis

# %%
car_details = car.copy()

# %%
car_details.head(15)
# Out:
#                                       year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire VDI                2014         450000     145500  Diesel
# Skoda Rapid 1.5 TDI Ambition          2014         370000     120000  Diesel
# Honda City 2017-2020 EXi              2006         158000     140000  Petrol
# Hyundai i20 Sportz Diesel             2010         225000     127000  Diesel
# Maruti Swift VXI BSIII                2007         130000     120000  Petrol
# Hyundai Xcent 1.2 VTVT E Plus         2017         440000      45000  Petrol
# Maruti Wagon R LXI DUO BSIII          2007          96000     175000     LPG
# Maruti 800 DX BSII                    2001          45000       5000  Petrol
# Toyota Etios VXD                      2011         350000      90000  Diesel
# Ford Figo Diesel Celebration Edition  2013         200000     169000  Diesel
# Renault Duster 110PS Diesel RxL       2014         500000      68000  Diesel
# Maruti Zen LX                         2005          92000     100000  Petrol
# Maruti Swift Dzire VDi                2009         280000     140000  Diesel
# Maruti Swift 1.3 VXi                  2007         200000      80000  Petrol
# Maruti Wagon R LXI Minor              2009         180000      90000  Petrol
#
#                                      seller_type transmission         owner  \
# name
# Maruti Swift Dzire VDI                Individual       Manual   First Owner
# Skoda Rapid 1.5 TDI Ambition          Individual       Manual  Second Owner
# Honda City 2017-2020 EXi              Individual       Manual   Third Owner
# Hyundai i20 Sportz Diesel             Individual       Manual   First Owner
# Maruti Swift VXI BSIII                Individual       Manual   First Owner
# Hyundai Xcent 1.2 VTVT E Plus         Individual       Manual   First Owner
# Maruti Wagon R LXI DUO BSIII          Individual       Manual   First Owner
# Maruti 800 DX BSII                    Individual       Manual  Second Owner
# Toyota Etios VXD                      Individual       Manual   First Owner
# Ford Figo Diesel Celebration Edition  Individual       Manual   First Owner
# Renault Duster 110PS Diesel RxL       Individual       Manual  Second Owner
# Maruti Zen LX                         Individual       Manual  Second Owner
# Maruti Swift Dzire VDi                Individual       Manual  Second Owner
# Maruti Swift 1.3 VXi                  Individual       Manual  Second Owner
# Maruti Wagon R LXI Minor              Individual       Manual  Second Owner
#
#                                          mileage   engine   max_power  \
# name
# Maruti Swift Dzire VDI                 23.4 kmpl  1248 CC      74 bhp
# Skoda Rapid 1.5 TDI Ambition          21.14 kmpl  1498 CC  103.52 bhp
# Honda City 2017-2020 EXi               17.7 kmpl  1497 CC      78 bhp
# Hyundai i20 Sportz Diesel              23.0 kmpl  1396 CC      90 bhp
# Maruti Swift VXI BSIII                 16.1 kmpl  1298 CC    88.2 bhp
# Hyundai Xcent 1.2 VTVT E Plus         20.14 kmpl  1197 CC   81.86 bhp
# Maruti Wagon R LXI DUO BSIII          17.3 km/kg  1061 CC    57.5 bhp
# Maruti 800 DX BSII                     16.1 kmpl   796 CC      37 bhp
# Toyota Etios VXD                      23.59 kmpl  1364 CC    67.1 bhp
# Ford Figo Diesel Celebration Edition   20.0 kmpl  1399 CC    68.1 bhp
# Renault Duster 110PS Diesel RxL       19.01 kmpl  1461 CC  108.45 bhp
# Maruti Zen LX                          17.3 kmpl   993 CC      60 bhp
# Maruti Swift Dzire VDi                 19.3 kmpl  1248 CC    73.9 bhp
# Maruti Swift 1.3 VXi                         NaN      NaN         NaN
# Maruti Wagon R LXI Minor               18.9 kmpl  1061 CC      67 bhp
#
#                                                         torque  seats
# name
# Maruti Swift Dzire VDI                          190Nm@ 2000rpm    5.0
# Skoda Rapid 1.5 TDI Ambition               250Nm@ 1500-2500rpm    5.0
# Honda City 2017-2020 EXi                 12.7@ 2,700(kgm@ rpm)    5.0
# Hyundai i20 Sportz Diesel             22.4 kgm at 1750-2750rpm    5.0
# Maruti Swift VXI BSIII                   11.5@ 4,500(kgm@ rpm)    5.0
# Hyundai Xcent 1.2 VTVT E Plus                113.75nm@ 4000rpm    5.0
# Maruti Wagon R LXI DUO BSIII              7.8@ 4,500(kgm@ rpm)    5.0
# Maruti 800 DX BSII                               59Nm@ 2500rpm    4.0
# Toyota Etios VXD                           170Nm@ 1800-2400rpm    5.0
# Ford Figo Diesel Celebration Edition            160Nm@ 2000rpm    5.0
# Renault Duster 110PS Diesel RxL                 248Nm@ 2250rpm    5.0
# Maruti Zen LX                                    78Nm@ 4500rpm    5.0
# Maruti Swift Dzire VDi                          190Nm@ 2000rpm    5.0
# Maruti Swift 1.3 VXi                                       NaN    NaN
# Maruti Wagon R LXI Minor                         84Nm@ 3500rpm    5.0

# %% [markdown]
# ## Checking the correlation before cleaning the data

# %%
car_details.corr()
# Out:
#                    year  selling_price  km_driven     seats
# year           1.000000       0.414092  -0.418006 -0.009144
# selling_price  0.414092       1.000000  -0.225534  0.041358
# km_driven     -0.418006      -0.225534   1.000000  0.227336
# seats         -0.009144       0.041358   0.227336  1.000000

# %% [markdown]
# ## Here we are getting highest correlation coefficient between 'year' and 'seling_price' which is 0.414092 . But the other attributes like: 'mileage', 'engine', 'max_power' and 'torque' seem to be numeric and may have some correlation with the selling price.

# %% [markdown]
# ## we have to convert 'mileage', 'engine', 'max_power', 'torque' to numerical attributes. We need to treat with the 'torque' attribute separately

# %%
attr = ['mileage', 'engine', 'max_power']
for i in attr:
    car_details[i] = car_details[i].apply(lambda x : (str(x).split(" ")[0]))

# %%
car_details[['mileage','engine','max_power']]
# Out:
#                              mileage engine max_power
# name
# Maruti Swift Dzire VDI          23.4   1248        74
# Skoda Rapid 1.5 TDI Ambition   21.14   1498    103.52
# Honda City 2017-2020 EXi        17.7   1497        78
# Hyundai i20 Sportz Diesel       23.0   1396        90
# Maruti Swift VXI BSIII          16.1   1298      88.2
# ...                              ...    ...       ...
# Hyundai i20 Magna               18.5   1197     82.85
# Hyundai Verna CRDi SX           16.8   1493       110
# Maruti Swift Dzire ZDi          19.3   1248      73.9
# Tata Indigo CR4                23.57   1396        70
# Tata Indigo CR4                23.57   1396        70
#
# [8128 rows x 3 columns]

# %%
car_details.head(15)
# Out:
#                                       year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire VDI                2014         450000     145500  Diesel
# Skoda Rapid 1.5 TDI Ambition          2014         370000     120000  Diesel
# Honda City 2017-2020 EXi              2006         158000     140000  Petrol
# Hyundai i20 Sportz Diesel             2010         225000     127000  Diesel
# Maruti Swift VXI BSIII                2007         130000     120000  Petrol
# Hyundai Xcent 1.2 VTVT E Plus         2017         440000      45000  Petrol
# Maruti Wagon R LXI DUO BSIII          2007          96000     175000     LPG
# Maruti 800 DX BSII                    2001          45000       5000  Petrol
# Toyota Etios VXD                      2011         350000      90000  Diesel
# Ford Figo Diesel Celebration Edition  2013         200000     169000  Diesel
# Renault Duster 110PS Diesel RxL       2014         500000      68000  Diesel
# Maruti Zen LX                         2005          92000     100000  Petrol
# Maruti Swift Dzire VDi                2009         280000     140000  Diesel
# Maruti Swift 1.3 VXi                  2007         200000      80000  Petrol
# Maruti Wagon R LXI Minor              2009         180000      90000  Petrol
#
#                                      seller_type transmission         owner  \
# name
# Maruti Swift Dzire VDI                Individual       Manual   First Owner
# Skoda Rapid 1.5 TDI Ambition          Individual       Manual  Second Owner
# Honda City 2017-2020 EXi              Individual       Manual   Third Owner
# Hyundai i20 Sportz Diesel             Individual       Manual   First Owner
# Maruti Swift VXI BSIII                Individual       Manual   First Owner
# Hyundai Xcent 1.2 VTVT E Plus         Individual       Manual   First Owner
# Maruti Wagon R LXI DUO BSIII          Individual       Manual   First Owner
# Maruti 800 DX BSII                    Individual       Manual  Second Owner
# Toyota Etios VXD                      Individual       Manual   First Owner
# Ford Figo Diesel Celebration Edition  Individual       Manual   First Owner
# Renault Duster 110PS Diesel RxL       Individual       Manual  Second Owner
# Maruti Zen LX                         Individual       Manual  Second Owner
# Maruti Swift Dzire VDi                Individual       Manual  Second Owner
# Maruti Swift 1.3 VXi                  Individual       Manual  Second Owner
# Maruti Wagon R LXI Minor              Individual       Manual  Second Owner
#
#                                      mileage engine max_power  \
# name
# Maruti Swift Dzire VDI                  23.4   1248        74
# Skoda Rapid 1.5 TDI Ambition           21.14   1498    103.52
# Honda City 2017-2020 EXi                17.7   1497        78
# Hyundai i20 Sportz Diesel               23.0   1396        90
# Maruti Swift VXI BSIII                  16.1   1298      88.2
# Hyundai Xcent 1.2 VTVT E Plus          20.14   1197     81.86
# Maruti Wagon R LXI DUO BSIII            17.3   1061      57.5
# Maruti 800 DX BSII                      16.1    796        37
# Toyota Etios VXD                       23.59   1364      67.1
# Ford Figo Diesel Celebration Edition    20.0   1399      68.1
# Renault Duster 110PS Diesel RxL        19.01   1461    108.45
# Maruti Zen LX                           17.3    993        60
# Maruti Swift Dzire VDi                  19.3   1248      73.9
# Maruti Swift 1.3 VXi                     nan    nan       nan
# Maruti Wagon R LXI Minor                18.9   1061        67
#
#                                                         torque  seats
# name
# Maruti Swift Dzire VDI                          190Nm@ 2000rpm    5.0
# Skoda Rapid 1.5 TDI Ambition               250Nm@ 1500-2500rpm    5.0
# Honda City 2017-2020 EXi                 12.7@ 2,700(kgm@ rpm)    5.0
# Hyundai i20 Sportz Diesel             22.4 kgm at 1750-2750rpm    5.0
# Maruti Swift VXI BSIII                   11.5@ 4,500(kgm@ rpm)    5.0
# Hyundai Xcent 1.2 VTVT E Plus                113.75nm@ 4000rpm    5.0
# Maruti Wagon R LXI DUO BSIII              7.8@ 4,500(kgm@ rpm)    5.0
# Maruti 800 DX BSII                               59Nm@ 2500rpm    4.0
# Toyota Etios VXD                           170Nm@ 1800-2400rpm    5.0
# Ford Figo Diesel Celebration Edition            160Nm@ 2000rpm    5.0
# Renault Duster 110PS Diesel RxL                 248Nm@ 2250rpm    5.0
# Maruti Zen LX                                    78Nm@ 4500rpm    5.0
# Maruti Swift Dzire VDi                          190Nm@ 2000rpm    5.0
# Maruti Swift 1.3 VXi                                       NaN    NaN
# Maruti Wagon R LXI Minor                         84Nm@ 3500rpm    5.0

# %% [markdown]
# ## Converting the 'mileage', 'engine', 'max_power' to numeric from text or object type

# %%
attr = ['mileage', 'engine', 'max_power']
for i in attr:
    car_details[i] = pd.to_numeric(car_details[i],errors = 'coerce')

# %%
car_details.head(15)
# Out:
#                                       year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire VDI                2014         450000     145500  Diesel
# Skoda Rapid 1.5 TDI Ambition          2014         370000     120000  Diesel
# Honda City 2017-2020 EXi              2006         158000     140000  Petrol
# Hyundai i20 Sportz Diesel             2010         225000     127000  Diesel
# Maruti Swift VXI BSIII                2007         130000     120000  Petrol
# Hyundai Xcent 1.2 VTVT E Plus         2017         440000      45000  Petrol
# Maruti Wagon R LXI DUO BSIII          2007          96000     175000     LPG
# Maruti 800 DX BSII                    2001          45000       5000  Petrol
# Toyota Etios VXD                      2011         350000      90000  Diesel
# Ford Figo Diesel Celebration Edition  2013         200000     169000  Diesel
# Renault Duster 110PS Diesel RxL       2014         500000      68000  Diesel
# Maruti Zen LX                         2005          92000     100000  Petrol
# Maruti Swift Dzire VDi                2009         280000     140000  Diesel
# Maruti Swift 1.3 VXi                  2007         200000      80000  Petrol
# Maruti Wagon R LXI Minor              2009         180000      90000  Petrol
#
#                                      seller_type transmission         owner  \
# name
# Maruti Swift Dzire VDI                Individual       Manual   First Owner
# Skoda Rapid 1.5 TDI Ambition          Individual       Manual  Second Owner
# Honda City 2017-2020 EXi              Individual       Manual   Third Owner
# Hyundai i20 Sportz Diesel             Individual       Manual   First Owner
# Maruti Swift VXI BSIII                Individual       Manual   First Owner
# Hyundai Xcent 1.2 VTVT E Plus         Individual       Manual   First Owner
# Maruti Wagon R LXI DUO BSIII          Individual       Manual   First Owner
# Maruti 800 DX BSII                    Individual       Manual  Second Owner
# Toyota Etios VXD                      Individual       Manual   First Owner
# Ford Figo Diesel Celebration Edition  Individual       Manual   First Owner
# Renault Duster 110PS Diesel RxL       Individual       Manual  Second Owner
# Maruti Zen LX                         Individual       Manual  Second Owner
# Maruti Swift Dzire VDi                Individual       Manual  Second Owner
# Maruti Swift 1.3 VXi                  Individual       Manual  Second Owner
# Maruti Wagon R LXI Minor              Individual       Manual  Second Owner
#
#                                       mileage  engine  max_power  \
# name
# Maruti Swift Dzire VDI                  23.40  1248.0      74.00
# Skoda Rapid 1.5 TDI Ambition            21.14  1498.0     103.52
# Honda City 2017-2020 EXi                17.70  1497.0      78.00
# Hyundai i20 Sportz Diesel               23.00  1396.0      90.00
# Maruti Swift VXI BSIII                  16.10  1298.0      88.20
# Hyundai Xcent 1.2 VTVT E Plus           20.14  1197.0      81.86
# Maruti Wagon R LXI DUO BSIII            17.30  1061.0      57.50
# Maruti 800 DX BSII                      16.10   796.0      37.00
# Toyota Etios VXD                        23.59  1364.0      67.10
# Ford Figo Diesel Celebration Edition    20.00  1399.0      68.10
# Renault Duster 110PS Diesel RxL         19.01  1461.0     108.45
# Maruti Zen LX                           17.30   993.0      60.00
# Maruti Swift Dzire VDi                  19.30  1248.0      73.90
# Maruti Swift 1.3 VXi                      NaN     NaN        NaN
# Maruti Wagon R LXI Minor                18.90  1061.0      67.00
#
#                                                         torque  seats
# name
# Maruti Swift Dzire VDI                          190Nm@ 2000rpm    5.0
# Skoda Rapid 1.5 TDI Ambition               250Nm@ 1500-2500rpm    5.0
# Honda City 2017-2020 EXi                 12.7@ 2,700(kgm@ rpm)    5.0
# Hyundai i20 Sportz Diesel             22.4 kgm at 1750-2750rpm    5.0
# Maruti Swift VXI BSIII                   11.5@ 4,500(kgm@ rpm)    5.0
# Hyundai Xcent 1.2 VTVT E Plus                113.75nm@ 4000rpm    5.0
# Maruti Wagon R LXI DUO BSIII              7.8@ 4,500(kgm@ rpm)    5.0
# Maruti 800 DX BSII                               59Nm@ 2500rpm    4.0
# Toyota Etios VXD                           170Nm@ 1800-2400rpm    5.0
# Ford Figo Diesel Celebration Edition            160Nm@ 2000rpm    5.0
# Renault Duster 110PS Diesel RxL                 248Nm@ 2250rpm    5.0
# Maruti Zen LX                                    78Nm@ 4500rpm    5.0
# Maruti Swift Dzire VDi                          190Nm@ 2000rpm    5.0
# Maruti Swift 1.3 VXi                                       NaN    NaN
# Maruti Wagon R LXI Minor                         84Nm@ 3500rpm    5.0

# %%
car_details[['mileage','engine','max_power']]
# Out:
#                               mileage  engine  max_power
# name
# Maruti Swift Dzire VDI          23.40  1248.0      74.00
# Skoda Rapid 1.5 TDI Ambition    21.14  1498.0     103.52
# Honda City 2017-2020 EXi        17.70  1497.0      78.00
# Hyundai i20 Sportz Diesel       23.00  1396.0      90.00
# Maruti Swift VXI BSIII          16.10  1298.0      88.20
# ...                               ...     ...        ...
# Hyundai i20 Magna               18.50  1197.0      82.85
# Hyundai Verna CRDi SX           16.80  1493.0     110.00
# Maruti Swift Dzire ZDi          19.30  1248.0      73.90
# Tata Indigo CR4                 23.57  1396.0      70.00
# Tata Indigo CR4                 23.57  1396.0      70.00
#
# [8128 rows x 3 columns]

# %%
car_details.dtypes
# Out:
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage          float64
# engine           float64
# max_power        float64
# torque            object
# seats            float64
# dtype: object

# %% [markdown]
# ## As we can see that 'Mileage', 'Engine', 'Max_Power' these attributes have been converted to Float Type

# %%
car_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8128 entries, Maruti Swift Dzire VDI to Tata Indigo CR4
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8128 non-null   int64
#  1   selling_price  8128 non-null   int64
#  2   km_driven      8128 non-null   int64
#  3   fuel           8128 non-null   object
#  4   seller_type    8128 non-null   object
#  5   transmission   8128 non-null   object
#  6   owner          8128 non-null   object
#  7   mileage        7907 non-null   float64
#  8   engine         7907 non-null   float64
#  9   max_power      7912 non-null   float64
#  10  torque         7906 non-null   object
#  11  seats          7907 non-null   float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 825.5+ KB

# %%
corr = car_details.corr()

# %%
corr
# Out:
#                    year  selling_price  km_driven   mileage    engine  \
# year           1.000000       0.414092  -0.418006  0.329145  0.018848
# selling_price  0.414092       1.000000  -0.225534 -0.126054  0.455734
# km_driven     -0.418006      -0.225534   1.000000 -0.173073  0.205914
# mileage        0.329145      -0.126054  -0.173073  1.000000 -0.575831
# engine         0.018848       0.455734   0.205914 -0.575831  1.000000
# max_power      0.226320       0.748489  -0.038075 -0.374621  0.703975
# seats         -0.009144       0.041358   0.227336 -0.452085  0.610309
#
#                max_power     seats
# year            0.226320 -0.009144
# selling_price   0.748489  0.041358
# km_driven      -0.038075  0.227336
# mileage        -0.374621 -0.452085
# engine          0.703975  0.610309
# max_power       1.000000  0.191999
# seats           0.191999  1.000000

# %%
corr.selling_price.sort_values(ascending=False)
# Out:
# selling_price    1.000000
# max_power        0.748489
# engine           0.455734
# year             0.414092
# seats            0.041358
# mileage         -0.126054
# km_driven       -0.225534
# Name: selling_price, dtype: float64

# %% [markdown]
# ## 'selling_price' has the highest correlation with 'max_power' having approx value 0.75

# %%
sns.heatmap(car_details.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
car_details['torque']
# Out:
# name
# Maruti Swift Dzire VDI                     190Nm@ 2000rpm
# Skoda Rapid 1.5 TDI Ambition          250Nm@ 1500-2500rpm
# Honda City 2017-2020 EXi            12.7@ 2,700(kgm@ rpm)
# Hyundai i20 Sportz Diesel        22.4 kgm at 1750-2750rpm
# Maruti Swift VXI BSIII              11.5@ 4,500(kgm@ rpm)
#                                           ...
# Hyundai i20 Magna                        113.7Nm@ 4000rpm
# Hyundai Verna CRDi SX           24@ 1,900-2,750(kgm@ rpm)
# Maruti Swift Dzire ZDi                     190Nm@ 2000rpm
# Tata Indigo CR4                       140Nm@ 1800-3000rpm
# Tata Indigo CR4                       140Nm@ 1800-3000rpm
# Name: torque, Length: 8128, dtype: object

# %%
car['torque'].value_counts()
# Out:
# 190Nm@ 2000rpm             530
# 200Nm@ 1750rpm             445
# 90Nm@ 3500rpm              405
# 113Nm@ 4200rpm             223
# 114Nm@ 4000rpm             171
#                           ...
# 380Nm(38.7kgm)@ 2500rpm      1
# 190@ 21,800(kgm@ rpm)        1
# 640Nm@ 1740rpm               1
# 130Nm@ 3000rpm               1
# 350Nm@ 1500-3500rpm          1
# Name: torque, Length: 441, dtype: int64

# %% [markdown]
# ### From this torque attribute we can say that it's extremely unorganized and the first few values have higher counts of vehicles and this count goes on gradually decreasing

# %% [markdown]
# ## Seeing the name of all the columns of the dataframe

# %%
car_details.columns
# Out:
# Index(['year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %% [markdown]
# ## Finding the number of unique values of all the attributes of the 'car_details' dataframe:

# %%
for i in car_details.columns:
    print(f'The number of unique values in {i} is : ',car_details[i].nunique())
#    print("The number of unique values in "+ i +" is :", len(car_details[i].value_counts()) )
# Out:
# The number of unique values in year is :  29
# The number of unique values in selling_price is :  677
# The number of unique values in km_driven is :  921
# The number of unique values in fuel is :  4
# The number of unique values in seller_type is :  3
# The number of unique values in transmission is :  2
# The number of unique values in owner is :  5
# The number of unique values in mileage is :  381
# The number of unique values in engine is :  121
# The number of unique values in max_power is :  319
# The number of unique values in torque is :  441
# The number of unique values in seats is :  9

# %%
type(pd.to_datetime('today').year)
# Out:
# int

# %% [markdown]
# ## showing the unique values of the attributes

# %%
car_details['year'].unique()
# Out:
# array([2014, 2006, 2010, 2007, 2017, 2001, 2011, 2013, 2005, 2009, 2016,
#        2012, 2002, 2015, 2018, 2003, 2019, 2008, 2020, 1999, 2000, 1983,
#        2004, 1996, 1994, 1995, 1998, 1997, 1991], dtype=int64)

# %%
car_details['year'].min()
# Out:
# 1983

# %%
car_details['year'].max()
# Out:
# 2020

# %%
car_details['km_driven'].unique()[:10]            # showing first 10 values
# Out:
# array([145500, 120000, 140000, 127000,  45000, 175000,   5000,  90000,
#        169000,  68000], dtype=int64)

# %%
car_details['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
car_details['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
car_details['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
car_details['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
car_details['mileage'].unique()[:10]               # showing first 10 values
# Out:
# array([23.4 , 21.14, 17.7 , 23.  , 16.1 , 20.14, 17.3 , 23.59, 20.  ,
#        19.01])

# %%
car_details['engine'].unique()
# Out:
# array([1248., 1498., 1497., 1396., 1298., 1197., 1061.,  796., 1364.,
#        1399., 1461.,  993.,   nan, 1198., 1199.,  998., 1591., 2179.,
#        1368., 2982., 2494., 2143., 2477., 1462., 2755., 1968., 1798.,
#        1196., 1373., 1598., 1998., 1086., 1194., 1172., 1405., 1582.,
#         999., 2487., 1999., 3604., 2987., 1995., 1451., 1969., 2967.,
#        2497., 1797., 1991., 2362., 1493., 1599., 1341., 1794.,  799.,
#        1193., 2696., 1495., 1186., 1047., 2498., 2956., 2523., 1120.,
#         624., 1496., 1984., 2354.,  814.,  793., 1799.,  936., 1956.,
#        1997., 1499., 1948., 2997., 2489., 2499., 2609., 2953., 1150.,
#        1994., 1388., 1527., 2199.,  995., 2993., 1586., 1390.,  909.,
#        2393., 3198., 1339., 2835., 2092., 1595., 2496., 1596., 1597.,
#        2596., 2148., 1299., 1590., 2231., 2694., 2200., 1795., 1896.,
#        1796., 1422., 1489., 2359., 2197., 2999., 1781., 2650., 1343.,
#        2446., 3498., 2198., 2776., 1950.])

# %%
car_details['max_power'].unique()[:30]         # showing first 30 values
# Out:
# array([ 74.  , 103.52,  78.  ,  90.  ,  88.2 ,  81.86,  57.5 ,  37.  ,
#         67.1 ,  68.1 , 108.45,  60.  ,  73.9 ,    nan,  67.  ,  82.  ,
#         88.5 ,  46.3 ,  88.73,  64.1 ,  98.6 ,  88.8 ,  83.81,  83.1 ,
#         47.3 ,  73.8 ,  34.2 ,  35.  ,  81.83,  40.3 ])

# %%
car_details['torque'].unique()[:40]            # showing first 40 values
# Out:
# array(['190Nm@ 2000rpm', '250Nm@ 1500-2500rpm', '12.7@ 2,700(kgm@ rpm)',
#        '22.4 kgm at 1750-2750rpm', '11.5@ 4,500(kgm@ rpm)',
#        '113.75nm@ 4000rpm', '7.8@ 4,500(kgm@ rpm)', '59Nm@ 2500rpm',
#        '170Nm@ 1800-2400rpm', '160Nm@ 2000rpm', '248Nm@ 2250rpm',
#        '78Nm@ 4500rpm', nan, '84Nm@ 3500rpm', '115Nm@ 3500-3600rpm',
#        '200Nm@ 1750rpm', '62Nm@ 3000rpm', '219.7Nm@ 1500-2750rpm',
#        '114Nm@ 3500rpm', '115Nm@ 4000rpm', '69Nm@ 3500rpm',
#        '172.5Nm@ 1750rpm', '6.1kgm@ 3000rpm', '114.7Nm@ 4000rpm',
#        '60Nm@ 3500rpm', '90Nm@ 3500rpm', '151Nm@ 4850rpm',
#        '104Nm@ 4000rpm', '320Nm@ 1700-2700rpm', '250Nm@ 1750-2500rpm',
#        '145Nm@ 4600rpm', '146Nm@ 4800rpm', '343Nm@ 1400-3400rpm',
#        '200Nm@ 1400-3400rpm', '200Nm@ 1250-4000rpm',
#        '400Nm@ 2000-2500rpm', '138Nm@ 4400rpm', '360Nm@ 1200-3400rpm',
#        '200Nm@ 1200-3600rpm', '380Nm@ 1750-2500rpm'], dtype=object)

# %% [markdown]
# ## The insight from 'torque' column is not much clear as the values for each instance are not in proper orientation. So we are dropping that attribute from this dataframe.

# %%
car_details = car_details.drop('torque', axis=1)

# %%
car_details.columns    # After dropping the 'torque' attribute
# Out:
# Index(['year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='object')

# %%
car_details['seats'].unique()
# Out:
# array([ 5.,  4., nan,  7.,  8.,  6.,  9., 10., 14.,  2.])

# %%
pd.to_datetime('today')
# Out:
# Timestamp('2021-12-03 00:38:58.259214')

# %%
pd.to_datetime('today').year
# Out:
# 2021

# %% [markdown]
# ## Adding a new column for the purpose of EDA to check the selling price variation with respect to 'year of service'

# %%
car_details['Year_of_service'] = car_details['year'].apply(lambda x : pd.to_datetime('today').year - x)

# %%
car_details[['year','Year_of_service']].head()
# Out:
#                               year  Year_of_service
# name
# Maruti Swift Dzire VDI        2014                7
# Skoda Rapid 1.5 TDI Ambition  2014                7
# Honda City 2017-2020 EXi      2006               15
# Hyundai i20 Sportz Diesel     2010               11
# Maruti Swift VXI BSIII        2007               14

# %%
corr1 = car_details.corr()

# %%
corr1
# Out:
#                      year  selling_price  km_driven   mileage    engine  \
# year             1.000000       0.414092  -0.418006  0.329145  0.018848
# selling_price    0.414092       1.000000  -0.225534 -0.126054  0.455734
# km_driven       -0.418006      -0.225534   1.000000 -0.173073  0.205914
# mileage          0.329145      -0.126054  -0.173073  1.000000 -0.575831
# engine           0.018848       0.455734   0.205914 -0.575831  1.000000
# max_power        0.226320       0.748489  -0.038075 -0.374621  0.703975
# seats           -0.009144       0.041358   0.227336 -0.452085  0.610309
# Year_of_service -1.000000      -0.414092   0.418006 -0.329145 -0.018848
#
#                  max_power     seats  Year_of_service
# year              0.226320 -0.009144        -1.000000
# selling_price     0.748489  0.041358        -0.414092
# km_driven        -0.038075  0.227336         0.418006
# mileage          -0.374621 -0.452085        -0.329145
# engine            0.703975  0.610309        -0.018848
# max_power         1.000000  0.191999        -0.226320
# seats             0.191999  1.000000         0.009144
# Year_of_service  -0.226320  0.009144         1.000000

# %% [markdown]
# ## Univariate Analysis: Making Box Plot of the numeric attributes to check if there is any outliers

# %% [markdown]
# ## Box plot of 'max_power' attribute:

# %%
sns.boxplot(y='max_power', data=car_details)
# Out:
# <AxesSubplot:ylabel='max_power'>

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='year', y='max_power',data=car_details)
# Out:
# <AxesSubplot:xlabel='year', ylabel='max_power'>

# %% [markdown]
# ## Statistical summary for the object type attributes

# %%
car_details.describe(include=object)
# Out:
#           fuel seller_type transmission        owner
# count     8128        8128         8128         8128
# unique       4           3            2            5
# top     Diesel  Individual       Manual  First Owner
# freq      4402        6766         7078         5289

# %%
car_details['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %% [markdown]
# ## Fuel

# %%
sns.countplot(x='fuel',data=car_details)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %%
plt.figure()
car_details.groupby('fuel')['selling_price'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='fuel'>

# %% [markdown]
# #### As for each Fuel the mean selling price of car is varying huge so we can assume that fuel can be a good predictor or it may have a high influence on the selling price

# %%
#car_details['selling_price'].groupby(car_details['fuel']).std()

# %% [markdown]
# ## Owner

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='owner', data=car_details)
# Out:
# <AxesSubplot:xlabel='owner', ylabel='count'>

# %% [markdown]
# ## Checking Mean Selling price for individual group of different attributes

# %%
plt.figure()
car_details.groupby('owner')['selling_price'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='owner'>

# %%
plt.figure()
car_details.groupby('seller_type')['selling_price'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='seller_type'>

# %% [markdown]
# #### For Test Drive Car the the mean price is higher tha others

# %% [markdown]
# ## Transmission

# %%
sns.countplot(x='transmission',data=car_details)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='count'>

# %%
plt.figure()
car_details.groupby('transmission')['selling_price'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='transmission'>

# %% [markdown]
# ## Seller_type

# %%
sns.countplot(x='seller_type',data=car_details)
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='count'>

# %%
car_details.head()
# Out:
#                               year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire VDI        2014         450000     145500  Diesel
# Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# Honda City 2017-2020 EXi      2006         158000     140000  Petrol
# Hyundai i20 Sportz Diesel     2010         225000     127000  Diesel
# Maruti Swift VXI BSIII        2007         130000     120000  Petrol
#
#                              seller_type transmission         owner  mileage  \
# name
# Maruti Swift Dzire VDI        Individual       Manual   First Owner    23.40
# Skoda Rapid 1.5 TDI Ambition  Individual       Manual  Second Owner    21.14
# Honda City 2017-2020 EXi      Individual       Manual   Third Owner    17.70
# Hyundai i20 Sportz Diesel     Individual       Manual   First Owner    23.00
# Maruti Swift VXI BSIII        Individual       Manual   First Owner    16.10
#
#                               engine  max_power  seats  Year_of_service
# name
# Maruti Swift Dzire VDI        1248.0      74.00    5.0                7
# Skoda Rapid 1.5 TDI Ambition  1498.0     103.52    5.0                7
# Honda City 2017-2020 EXi      1497.0      78.00    5.0               15
# Hyundai i20 Sportz Diesel     1396.0      90.00    5.0               11
# Maruti Swift VXI BSIII        1298.0      88.20    5.0               14

# %%
car_details.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04    19.418783  1458.625016
# std       4.044249   8.062534e+05  5.655055e+04     4.037145   503.916303
# min    1983.000000   2.999900e+04  1.000000e+00     0.000000   624.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04    16.780000  1197.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04    19.300000  1248.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04    22.320000  1582.000000
# max    2020.000000   1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power        seats  Year_of_service
# count  7912.000000  7907.000000      8128.000000
# mean     91.517919     5.416719         7.195989
# std      35.822499     0.959588         4.044249
# min       0.000000     2.000000         1.000000
# 25%      68.050000     5.000000         4.000000
# 50%      82.000000     5.000000         6.000000
# 75%     102.000000     5.000000        10.000000
# max     400.000000    14.000000        38.000000

# %% [markdown]
# ## Histogram and KDE Plot of the numerical features before Outlier Treatment

# %%
sns.histplot(x='selling_price',data=car_details,bins=10,kde=True)
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='Count'>

# %%
sns.histplot(x='mileage',data=car_details,bins=10,kde=True)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='Count'>

# %%
sns.histplot(x='km_driven',data=car_details,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='Count'>

# %%
sns.histplot(x='engine',data=car_details,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='engine', ylabel='Count'>

# %%
sns.histplot(x='max_power',data=car_details,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='Count'>

# %%
sns.histplot(x='seats',data=car_details,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='seats', ylabel='Count'>

# %% [markdown]
# ## Bivariate Analysis(Scatter Plot) between the variables before OutLier Treatment to see the type of relationship

# %%
sns.scatterplot(x='mileage',y='selling_price',data=car_details, hue='fuel')
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='selling_price'>

# %% [markdown]
# ### Inference: Between 'mileage' and 'selling_price' the relation doesn't seem to be linear that much

# %%
sns.scatterplot(x='km_driven',y='selling_price',data=car_details, hue='fuel')
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='selling_price'>

# %%
sns.scatterplot(x='engine',y='selling_price',data=car_details, hue='fuel')
# Out:
# <AxesSubplot:xlabel='engine', ylabel='selling_price'>

# %%
sns.scatterplot(x='max_power',y='selling_price',data=car_details, hue='fuel')
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='selling_price'>

# %%
sns.scatterplot(x='seats',y='selling_price',data=car_details, hue='fuel')
# Out:
# <AxesSubplot:xlabel='seats', ylabel='selling_price'>

# %%
sns.regplot(x='seats', y='selling_price', data=car_details, color='red')
# Out:
# <AxesSubplot:xlabel='seats', ylabel='selling_price'>

# %% [markdown]
# ### Seats attribute doesn't seem to be a very good predictor of 'selling_price'. So we can remove this attribute

# %%
plt.figure(figsize=(10,6))
sns.lmplot(x='max_power',y='selling_price',markers='+',data=car_details,hue='fuel')

# %% [markdown]
# ### Inference: The Linear Model plot between 'max_power' and 'selling_price' is showing a good relationship for 'Petrol' and 'Diesel' driven car

# %%
plt.figure(figsize=(10,6))
sns.lmplot(x='max_power',y='selling_price',markers='+',data=car_details,hue='seller_type')

# %% [markdown]
# ### Inference: The Selling Price vs max_power is showing a good relationship for Individual and Dealer seller type car

# %%
plt.figure(figsize=(10,6))
sns.lmplot(x='Year_of_service',y='selling_price',markers='+',data=car_details,hue='fuel')

# %%
plt.figure(figsize=(12,4))
sns.regplot(x='max_power', y='selling_price', data=car_details,marker ='o',color='red')
plt.show()

# %% [markdown]
# ### From the Exploratory Data Analysis we can say that if any car has high value of max_power and if it's "Diesel driven" as well as seller type is "Dealer" and if its transmission type is "Automatic" then its price will be higher. More over higher the year of service lower the selling price is also noticed.

# %% [markdown]
# # Outliers Treatment

# %% [markdown]
# ## Replacing all detected outliers of max_power attribute using median of this attribute

# %%
car1 = car_details.copy()

# %%
#i = car1[(car1['max_power']>= 150) & (car1['max_power']<= 400)].index

# %%
car1['max_power'].median(), car1['max_power'].mean()
# Out:
# (82.0, 91.51791898382159)

# %%
car_details.shape
# Out:
# (8128, 12)

# %%
car1.shape
# Out:
# (8128, 12)

# %%
car1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8128 entries, Maruti Swift Dzire VDI to Tata Indigo CR4
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             8128 non-null   int64
#  1   selling_price    8128 non-null   int64
#  2   km_driven        8128 non-null   int64
#  3   fuel             8128 non-null   object
#  4   seller_type      8128 non-null   object
#  5   transmission     8128 non-null   object
#  6   owner            8128 non-null   object
#  7   mileage          7907 non-null   float64
#  8   engine           7907 non-null   float64
#  9   max_power        7912 non-null   float64
#  10  seats            7907 non-null   float64
#  11  Year_of_service  8128 non-null   int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 954.5+ KB

# %%
# Test code

power_dict = dict(car_details['max_power'].describe())

# %%
power_dict
# Out:
# {'count': 7912.0,
#  'mean': 91.51791898382159,
#  'std': 35.822498734732974,
#  'min': 0.0,
#  '25%': 68.05,
#  '50%': 82.0,
#  '75%': 102.0,
#  'max': 400.0}

# %%
power_dict['25%']
# Out:
# 68.05

# %% [markdown]
# ## User defined Function for detecting outliers

# %%
outliers = []
upper_lim = 0
lower_lim = 0
def outlier_detection(x):
    global outliers
    x_dict = dict(car_details[x].describe())
    print(x_dict)
    Q1 = x_dict['25%']
    print("Q1 :", Q1)
    Q3 = x_dict['75%']
    print("Q3 :", Q3)
    IQR = Q3 - Q1
    print("Inter quartile range is ", IQR)
    global lower_lim
    global upper_lim
    lower_lim = Q1 - 1.5 * IQR
    upper_lim = Q3 + 1.5 * IQR
    print("The lower limit is ", round(lower_lim))
    print("The upper limit is ", round(upper_lim))

    for i in car_details[x]:
        if ((i > upper_lim) | (i < lower_lim)):
            outliers.append(i)
#    print("The outliers of ", x ,"is :", outliers)

# %%
outlier_detection('max_power')
# Out:
# {'count': 7912.0, 'mean': 91.51791898382159, 'std': 35.822498734732974, 'min': 0.0, '25%': 68.05, '50%': 82.0, '75%': 102.0, 'max': 400.0}
# Q1 : 68.05
# Q3 : 102.0
# Inter quartile range is  33.95
# The lower limit is  17
# The upper limit is  153

# %%
min(outliers), max(outliers), len(outliers)
# Out:
# (0.0, 400.0, 570)

# %% [markdown]
# ### Identifying the instances which are outliers for 'max_power'

# %%
# Outliers above the upper whisker
car1.loc[(car1['max_power']>=153) & (car1['max_power']<=400)]
# Out:
#                                      year  selling_price  km_driven    fuel  \
# name
# Jeep Compass 1.4 Limited Plus BSIV   2019        2100000       5000  Petrol
# Toyota Fortuner 4x4 MT               2014        1500000      77000  Diesel
# Mitsubishi Pajero Sport 4X4          2013        1090000     151000  Diesel
# Toyota Innova Crysta 2.8 ZX AT BSIV  2016        1650000     127700  Diesel
# Audi A6 2.0 TDI Technology           2013        1750000      33900  Diesel
# ...                                   ...            ...        ...     ...
# BMW 3 Series 320d Sedan              2011        1500000      84925  Diesel
# Hyundai Santa Fe 4x4 AT              2011        1200000      62000  Diesel
# Honda CR-V 2.4L 4WD AT               2012         750000      50171  Petrol
# Honda Accord 2.4 A/T                 2013         580000      50000  Petrol
# Audi A3 40 TFSI Premium              2017        1689999       8000  Petrol
#
#                                     seller_type transmission         owner  \
# name
# Jeep Compass 1.4 Limited Plus BSIV   Individual    Automatic   First Owner
# Toyota Fortuner 4x4 MT                   Dealer       Manual   First Owner
# Mitsubishi Pajero Sport 4X4              Dealer       Manual   First Owner
# Toyota Innova Crysta 2.8 ZX AT BSIV      Dealer    Automatic  Second Owner
# Audi A6 2.0 TDI Technology               Dealer    Automatic  Second Owner
# ...                                         ...          ...           ...
# BMW 3 Series 320d Sedan              Individual    Automatic   First Owner
# Hyundai Santa Fe 4x4 AT              Individual    Automatic  Second Owner
# Honda CR-V 2.4L 4WD AT                   Dealer    Automatic   First Owner
# Honda Accord 2.4 A/T                     Dealer    Automatic   First Owner
# Audi A3 40 TFSI Premium                  Dealer    Automatic   First Owner
#
#                                      mileage  engine  max_power  seats  \
# name
# Jeep Compass 1.4 Limited Plus BSIV     16.00  1368.0     160.77    5.0
# Toyota Fortuner 4x4 MT                 12.55  2982.0     168.50    7.0
# Mitsubishi Pajero Sport 4X4            13.50  2477.0     175.56    7.0
# Toyota Innova Crysta 2.8 ZX AT BSIV    11.36  2755.0     171.50    7.0
# Audi A6 2.0 TDI Technology             17.68  1968.0     174.33    5.0
# ...                                      ...     ...        ...    ...
# BMW 3 Series 320d Sedan                16.07  1995.0     181.00    5.0
# Hyundai Santa Fe 4x4 AT                11.72  2199.0     194.30    7.0
# Honda CR-V 2.4L 4WD AT                 11.10  2354.0     158.80    5.0
# Honda Accord 2.4 A/T                   11.70  2354.0     177.60    5.0
# Audi A3 40 TFSI Premium                16.60  1798.0     177.50    5.0
#
#                                      Year_of_service
# name
# Jeep Compass 1.4 Limited Plus BSIV                 2
# Toyota Fortuner 4x4 MT                             7
# Mitsubishi Pajero Sport 4X4                        8
# Toyota Innova Crysta 2.8 ZX AT BSIV                5
# Audi A6 2.0 TDI Technology                         8
# ...                                              ...
# BMW 3 Series 320d Sedan                           10
# Hyundai Santa Fe 4x4 AT                           10
# Honda CR-V 2.4L 4WD AT                             9
# Honda Accord 2.4 A/T                               8
# Audi A3 40 TFSI Premium                            4
#
# [564 rows x 12 columns]

# %%
# Outliers below the lower whisker
car1.loc[(car1['max_power']<=17)]
# Out:
#                                  year  selling_price  km_driven    fuel  \
# name
# Maruti Alto K10 LXI              2011         204999      97500  Petrol
# Maruti Alto K10 LXI              2011         204999      97500  Petrol
# Maruti Swift Dzire VDI Optional  2017         589000      41232  Diesel
# Maruti Swift Dzire VDI Optional  2017         589000      41232  Diesel
# Tata Indica Vista Quadrajet LS   2012         240000      70000  Diesel
# Tata Indica Vista Quadrajet LS   2012         240000      70000  Diesel
#
#                                 seller_type transmission        owner  \
# name
# Maruti Alto K10 LXI              Individual       Manual  First Owner
# Maruti Alto K10 LXI              Individual       Manual  First Owner
# Maruti Swift Dzire VDI Optional      Dealer       Manual  First Owner
# Maruti Swift Dzire VDI Optional      Dealer       Manual  First Owner
# Tata Indica Vista Quadrajet LS   Individual       Manual  First Owner
# Tata Indica Vista Quadrajet LS   Individual       Manual  First Owner
#
#                                  mileage  engine  max_power  seats  \
# name
# Maruti Alto K10 LXI                  NaN     NaN        0.0    NaN
# Maruti Alto K10 LXI                  NaN     NaN        0.0    NaN
# Maruti Swift Dzire VDI Optional      NaN     NaN        0.0    NaN
# Maruti Swift Dzire VDI Optional      NaN     NaN        0.0    NaN
# Tata Indica Vista Quadrajet LS       NaN     NaN        0.0    NaN
# Tata Indica Vista Quadrajet LS       NaN     NaN        0.0    NaN
#
#                                  Year_of_service
# name
# Maruti Alto K10 LXI                           10
# Maruti Alto K10 LXI                           10
# Maruti Swift Dzire VDI Optional                4
# Maruti Swift Dzire VDI Optional                4
# Tata Indica Vista Quadrajet LS                 9
# Tata Indica Vista Quadrajet LS                 9

# %%
round(upper_lim), round(lower_lim)
# Out:
# (153, 17)

# %%
car1.loc[((car1['max_power']>= 153) & (car1['max_power']<=400)), 'max_power' ]=round(upper_lim)

# %%
car1.loc[(car1['max_power']<=17), 'max_power']=round(lower_lim)

# %%
sns.boxplot(x='max_power', data=car1)
# Out:
# <AxesSubplot:xlabel='max_power'>

# %%
fig,axes = plt.subplots(nrows=2, ncols=2, figsize=(15,6))
sns.boxplot(x='max_power',data=car1,ax=axes[0,0])
axes[0,0].set_xlabel('Boxplot of max_power after outlier treatment')
sns.boxplot(x='max_power',data=car_details,ax=axes[0,1])
axes[0,1].set_xlabel('Boxplot of max_power before outlier treatment')
sns.histplot(x='max_power',data=car1,kde=True,ax=axes[1,0])
axes[1,0].set_xlabel('Histogram of max_power after outlier treatment')
sns.histplot(x='max_power',data=car_details,kde=True,ax=axes[1,1])
axes[1,1].set_xlabel('Histogram of max_power before outlier treatment')
# Out:
# Text(0.5, 0, 'Histogram of max_power before outlier treatment')

# %% [markdown]
# ## There are still few outliers left in the attribute but certailnly the number of outliers have been reduced. The distribution of the feature has been changed as well from right skewed to almost normal distribution

# %%
outliers.clear()
outlier_detection('engine')
# Out:
# {'count': 7907.0, 'mean': 1458.625015808777, 'std': 503.9163029923002, 'min': 624.0, '25%': 1197.0, '50%': 1248.0, '75%': 1582.0, 'max': 3604.0}
# Q1 : 1197.0
# Q3 : 1582.0
# Inter quartile range is  385.0
# The lower limit is  620
# The upper limit is  2160

# %%
min(outliers), max(outliers), len(outliers)
# Out:
# (2179.0, 3604.0, 1183)

# %% [markdown]
# ### Identifying the instances which are outliers for 'engine'

# %%
# Outliers above the upper whisker
car1.loc[(car1['engine']>=2160) & (car1['engine']<=3604)]
# Out:
#                                               year  selling_price  km_driven  \
# name
# Tata Safari DICOR 2.2 LX 4x2                  2011         425000      60000
# Toyota Fortuner 4x4 MT                        2014        1500000      77000
# Toyota Innova 2.5 G (Diesel) 7 Seater BS IV   2013         700000      99000
# Mitsubishi Pajero Sport 4X4                   2013        1090000     151000
# Toyota Innova Crysta 2.8 ZX AT BSIV           2016        1650000     127700
# ...                                            ...            ...        ...
# Toyota Innova 2.5 V Diesel 7-seater           2010         425000     200000
# Toyota Innova 2.5 E 7 STR                     2009         550000     250000
# Tata New Safari DICOR 2.2 EX 4x2              2010         300000     100000
# Mahindra XUV500 W8 2WD                        2013         750000     120000
# Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV  2010         425000     129000
#
#                                                 fuel seller_type transmission  \
# name
# Tata Safari DICOR 2.2 LX 4x2                  Diesel  Individual       Manual
# Toyota Fortuner 4x4 MT                        Diesel      Dealer       Manual
# Toyota Innova 2.5 G (Diesel) 7 Seater BS IV   Diesel      Dealer       Manual
# Mitsubishi Pajero Sport 4X4                   Diesel      Dealer       Manual
# Toyota Innova Crysta 2.8 ZX AT BSIV           Diesel      Dealer    Automatic
# ...                                              ...         ...          ...
# Toyota Innova 2.5 V Diesel 7-seater           Diesel  Individual       Manual
# Toyota Innova 2.5 E 7 STR                     Diesel  Individual       Manual
# Tata New Safari DICOR 2.2 EX 4x2              Diesel  Individual       Manual
# Mahindra XUV500 W8 2WD                        Diesel  Individual       Manual
# Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV  Diesel  Individual       Manual
#
#                                                      owner  mileage  engine  \
# name
# Tata Safari DICOR 2.2 LX 4x2                  Second Owner    13.93  2179.0
# Toyota Fortuner 4x4 MT                         First Owner    12.55  2982.0
# Toyota Innova 2.5 G (Diesel) 7 Seater BS IV    First Owner    12.99  2494.0
# Mitsubishi Pajero Sport 4X4                    First Owner    13.50  2477.0
# Toyota Innova Crysta 2.8 ZX AT BSIV           Second Owner    11.36  2755.0
# ...                                                    ...      ...     ...
# Toyota Innova 2.5 V Diesel 7-seater           Second Owner    12.80  2494.0
# Toyota Innova 2.5 E 7 STR                      First Owner    12.80  2494.0
# Tata New Safari DICOR 2.2 EX 4x2               First Owner    11.57  2179.0
# Mahindra XUV500 W8 2WD                         First Owner    15.10  2179.0
# Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV   First Owner    12.80  2494.0
#
#                                               max_power  seats  \
# name
# Tata Safari DICOR 2.2 LX 4x2                     138.03    7.0
# Toyota Fortuner 4x4 MT                           153.00    7.0
# Toyota Innova 2.5 G (Diesel) 7 Seater BS IV      100.00    7.0
# Mitsubishi Pajero Sport 4X4                      153.00    7.0
# Toyota Innova Crysta 2.8 ZX AT BSIV              153.00    7.0
# ...                                                 ...    ...
# Toyota Innova 2.5 V Diesel 7-seater              102.00    7.0
# Toyota Innova 2.5 E 7 STR                        102.00    7.0
# Tata New Safari DICOR 2.2 EX 4x2                 138.10    7.0
# Mahindra XUV500 W8 2WD                           140.00    7.0
# Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV     102.00    8.0
#
#                                               Year_of_service
# name
# Tata Safari DICOR 2.2 LX 4x2                               10
# Toyota Fortuner 4x4 MT                                      7
# Toyota Innova 2.5 G (Diesel) 7 Seater BS IV                 8
# Mitsubishi Pajero Sport 4X4                                 8
# Toyota Innova Crysta 2.8 ZX AT BSIV                         5
# ...                                                       ...
# Toyota Innova 2.5 V Diesel 7-seater                        11
# Toyota Innova 2.5 E 7 STR                                  12
# Tata New Safari DICOR 2.2 EX 4x2                           11
# Mahindra XUV500 W8 2WD                                      8
# Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV               11
#
# [1183 rows x 12 columns]

# %%
# Outliers below the lower whisker
car1.loc[(car1['engine']<=620)]
# Out:
# Empty DataFrame
# Columns: [year, selling_price, km_driven, fuel, seller_type, transmission, owner, mileage, engine, max_power, seats, Year_of_service]
# Index: []

# %%
round(upper_lim), round(lower_lim)
# Out:
# (2160, 620)

# %%
car1.loc[((car1['engine']>=2160) & (car1['engine']<=3604)), 'engine']=round(upper_lim)

# %% [markdown]
# ## Boxplot of 'engine' after outlier treatment

# %%
sns.boxplot(x='engine', data= car1)
# Out:
# <AxesSubplot:xlabel='engine'>

# %% [markdown]
# ## Box plot of 'engine' attribute before outlier treatment

# %%
sns.boxplot(x='engine', data=car_details)
# Out:
# <AxesSubplot:xlabel='engine'>

# %%
fig,axes = plt.subplots(nrows=2, ncols=2, figsize=(15,6))
sns.boxplot(x='engine',data=car1,ax=axes[0,0])
axes[0,0].set_xlabel('Boxplot of engine after outlier treatment')
sns.boxplot(x='engine',data=car_details,ax=axes[0,1])
axes[0,1].set_xlabel('Boxplot of engine before outlier treatment')
sns.histplot(x='engine',data=car1,kde=True,ax=axes[1,0])
axes[1,0].set_xlabel('Histogram of engine after outlier treatment')
sns.histplot(x='engine',data=car_details,kde=True,ax=axes[1,1])
axes[1,1].set_xlabel('Histogram of engine before outlier treatment')
# Out:
# Text(0.5, 0, 'Histogram of engine before outlier treatment')

# %%
outliers.clear()
outlier_detection('seats')
# Out:
# {'count': 7907.0, 'mean': 5.41671936259011, 'std': 0.95958752023394, 'min': 2.0, '25%': 5.0, '50%': 5.0, '75%': 5.0, 'max': 14.0}
# Q1 : 5.0
# Q3 : 5.0
# Inter quartile range is  0.0
# The lower limit is  5
# The upper limit is  5

# %% [markdown]
# ## Outliers for 'mileage'

# %%
outliers.clear()
outlier_detection('mileage')
# Out:
# {'count': 7907.0, 'mean': 19.418783356519516, 'std': 4.0371450567755565, 'min': 0.0, '25%': 16.78, '50%': 19.3, '75%': 22.32, 'max': 42.0}
# Q1 : 16.78
# Q3 : 22.32
# Inter quartile range is  5.539999999999999
# The lower limit is  8
# The upper limit is  31

# %%
min(outliers), max(outliers), len(outliers)
# Out:
# (0.0, 42.0, 24)

# %%
round(lower_lim), round(upper_lim)
# Out:
# (8, 31)

# %% [markdown]
# ### Identifying the instances which are outliers for 'mileage'

# %%
# Outliers above the upper whisker
car1.loc[(car1['mileage'] >= 31)]
# Out:
#                                   year  selling_price  km_driven    fuel  \
# name
# Maruti Alto 800 CNG LXI Optional  2019         330000      10000     CNG
# Volvo XC90 T8 Excellence BSIV     2017       10000000      30000  Petrol
# Maruti Wagon R CNG LXI            2013         270000      80000     CNG
# Maruti Alto 800 CNG LXI           2017         260000      67000     CNG
# Maruti Alto K10 LXI CNG           2019         430000      20000     CNG
# Maruti Alto 800 LXI CNG           2020         370000      16000     CNG
# Maruti Alto 800 CNG LXI Optional  2019         330000      10000     CNG
#
#                                  seller_type transmission         owner  \
# name
# Maruti Alto 800 CNG LXI Optional  Individual       Manual  Second Owner
# Volvo XC90 T8 Excellence BSIV     Individual    Automatic   First Owner
# Maruti Wagon R CNG LXI            Individual       Manual  Second Owner
# Maruti Alto 800 CNG LXI           Individual       Manual   First Owner
# Maruti Alto K10 LXI CNG           Individual       Manual   First Owner
# Maruti Alto 800 LXI CNG           Individual       Manual   First Owner
# Maruti Alto 800 CNG LXI Optional  Individual       Manual  Second Owner
#
#                                   mileage  engine  max_power  seats  \
# name
# Maruti Alto 800 CNG LXI Optional    33.44   796.0      40.30    4.0
# Volvo XC90 T8 Excellence BSIV       42.00  1969.0     153.00    4.0
# Maruti Wagon R CNG LXI              32.52   998.0      58.33    5.0
# Maruti Alto 800 CNG LXI             33.44   796.0      40.30    4.0
# Maruti Alto K10 LXI CNG             32.26   998.0      58.30    4.0
# Maruti Alto 800 LXI CNG             33.00   796.0      47.30    5.0
# Maruti Alto 800 CNG LXI Optional    33.44   796.0      40.30    4.0
#
#                                   Year_of_service
# name
# Maruti Alto 800 CNG LXI Optional                2
# Volvo XC90 T8 Excellence BSIV                   4
# Maruti Wagon R CNG LXI                          8
# Maruti Alto 800 CNG LXI                         4
# Maruti Alto K10 LXI CNG                         2
# Maruti Alto 800 LXI CNG                         1
# Maruti Alto 800 CNG LXI Optional                2

# %%
car1.loc[(car1['mileage'] >= 31),'mileage'] = round(upper_lim)

# %%
car1.loc[(car1['mileage'] >= 31)]
# Out:
#                                   year  selling_price  km_driven    fuel  \
# name
# Maruti Alto 800 CNG LXI Optional  2019         330000      10000     CNG
# Volvo XC90 T8 Excellence BSIV     2017       10000000      30000  Petrol
# Maruti Wagon R CNG LXI            2013         270000      80000     CNG
# Maruti Alto 800 CNG LXI           2017         260000      67000     CNG
# Maruti Alto K10 LXI CNG           2019         430000      20000     CNG
# Maruti Alto 800 LXI CNG           2020         370000      16000     CNG
# Maruti Alto 800 CNG LXI Optional  2019         330000      10000     CNG
#
#                                  seller_type transmission         owner  \
# name
# Maruti Alto 800 CNG LXI Optional  Individual       Manual  Second Owner
# Volvo XC90 T8 Excellence BSIV     Individual    Automatic   First Owner
# Maruti Wagon R CNG LXI            Individual       Manual  Second Owner
# Maruti Alto 800 CNG LXI           Individual       Manual   First Owner
# Maruti Alto K10 LXI CNG           Individual       Manual   First Owner
# Maruti Alto 800 LXI CNG           Individual       Manual   First Owner
# Maruti Alto 800 CNG LXI Optional  Individual       Manual  Second Owner
#
#                                   mileage  engine  max_power  seats  \
# name
# Maruti Alto 800 CNG LXI Optional     31.0   796.0      40.30    4.0
# Volvo XC90 T8 Excellence BSIV        31.0  1969.0     153.00    4.0
# Maruti Wagon R CNG LXI               31.0   998.0      58.33    5.0
# Maruti Alto 800 CNG LXI              31.0   796.0      40.30    4.0
# Maruti Alto K10 LXI CNG              31.0   998.0      58.30    4.0
# Maruti Alto 800 LXI CNG              31.0   796.0      47.30    5.0
# Maruti Alto 800 CNG LXI Optional     31.0   796.0      40.30    4.0
#
#                                   Year_of_service
# name
# Maruti Alto 800 CNG LXI Optional                2
# Volvo XC90 T8 Excellence BSIV                   4
# Maruti Wagon R CNG LXI                          8
# Maruti Alto 800 CNG LXI                         4
# Maruti Alto K10 LXI CNG                         2
# Maruti Alto 800 LXI CNG                         1
# Maruti Alto 800 CNG LXI Optional                2

# %%
# Outliers below the lower whisker
car1.loc[(car1['mileage'] <= 8)]
# Out:
#                                                    year  selling_price  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition  2009         135000
# Hyundai Santro Xing GL                             2009         120000
# Hyundai Santro Xing GL                             2008         105000
# Mercedes-Benz M-Class ML 350 4Matic                2011        1700000
# Land Rover Freelander 2 TD4 HSE                    2013        1650000
# Hyundai Santro Xing (Non-AC)                       2010         110000
# Hyundai Santro Xing (Non-AC)                       2013         184000
# Mercedes-Benz M-Class ML 350 4Matic                2011        1700000
# Hyundai Santro Xing GL                             2008         175000
# Volkswagen Polo GT TSI BSIV                        2014         574000
# Volkswagen Polo GT TSI BSIV                        2014         575000
# Mahindra Bolero Pik-Up FB 1.7T                     2020         679000
# Hyundai Santro Xing GL                             2010         150000
# Mahindra Bolero Pik-Up CBC 1.7T                    2019         722000
# Hyundai Santro Xing GL                             2011         150000
# Hyundai Santro Xing (Non-AC)                       2010         110000
# Mercedes-Benz GLC 220d 4MATIC                      2017        3300000
#
#                                                    km_driven    fuel  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition      28900  Petrol
# Hyundai Santro Xing GL                                 90000  Petrol
# Hyundai Santro Xing GL                                128000  Petrol
# Mercedes-Benz M-Class ML 350 4Matic                   110000  Diesel
# Land Rover Freelander 2 TD4 HSE                        64788  Diesel
# Hyundai Santro Xing (Non-AC)                           80000  Petrol
# Hyundai Santro Xing (Non-AC)                           15000  Petrol
# Mercedes-Benz M-Class ML 350 4Matic                   110000  Diesel
# Hyundai Santro Xing GL                                 40000  Petrol
# Volkswagen Polo GT TSI BSIV                            28080  Petrol
# Volkswagen Polo GT TSI BSIV                            28100  Petrol
# Mahindra Bolero Pik-Up FB 1.7T                          5000  Diesel
# Hyundai Santro Xing GL                                110000  Petrol
# Mahindra Bolero Pik-Up CBC 1.7T                        80000  Diesel
# Hyundai Santro Xing GL                                 40000  Petrol
# Hyundai Santro Xing (Non-AC)                           80000  Petrol
# Mercedes-Benz GLC 220d 4MATIC                          60000  Diesel
#
#                                                   seller_type transmission  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition  Individual       Manual
# Hyundai Santro Xing GL                             Individual       Manual
# Hyundai Santro Xing GL                             Individual       Manual
# Mercedes-Benz M-Class ML 350 4Matic                Individual    Automatic
# Land Rover Freelander 2 TD4 HSE                        Dealer    Automatic
# Hyundai Santro Xing (Non-AC)                       Individual       Manual
# Hyundai Santro Xing (Non-AC)                       Individual       Manual
# Mercedes-Benz M-Class ML 350 4Matic                Individual    Automatic
# Hyundai Santro Xing GL                             Individual       Manual
# Volkswagen Polo GT TSI BSIV                            Dealer    Automatic
# Volkswagen Polo GT TSI BSIV                            Dealer    Automatic
# Mahindra Bolero Pik-Up FB 1.7T                     Individual       Manual
# Hyundai Santro Xing GL                             Individual       Manual
# Mahindra Bolero Pik-Up CBC 1.7T                    Individual       Manual
# Hyundai Santro Xing GL                             Individual       Manual
# Hyundai Santro Xing (Non-AC)                       Individual       Manual
# Mercedes-Benz GLC 220d 4MATIC                          Dealer    Automatic
#
#                                                                   owner  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition          Second Owner
# Hyundai Santro Xing GL                                     Second Owner
# Hyundai Santro Xing GL                                      First Owner
# Mercedes-Benz M-Class ML 350 4Matic                         Third Owner
# Land Rover Freelander 2 TD4 HSE                             First Owner
# Hyundai Santro Xing (Non-AC)                               Second Owner
# Hyundai Santro Xing (Non-AC)                                First Owner
# Mercedes-Benz M-Class ML 350 4Matic                         Third Owner
# Hyundai Santro Xing GL                                      First Owner
# Volkswagen Polo GT TSI BSIV                                 First Owner
# Volkswagen Polo GT TSI BSIV                                 First Owner
# Mahindra Bolero Pik-Up FB 1.7T                              First Owner
# Hyundai Santro Xing GL                                      First Owner
# Mahindra Bolero Pik-Up CBC 1.7T                             First Owner
# Hyundai Santro Xing GL                             Fourth & Above Owner
# Hyundai Santro Xing (Non-AC)                               Second Owner
# Mercedes-Benz GLC 220d 4MATIC                               First Owner
#
#                                                    mileage  engine  max_power  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition      0.0  1172.0      65.00
# Hyundai Santro Xing GL                                 0.0  1086.0      62.00
# Hyundai Santro Xing GL                                 0.0  1086.0      62.00
# Mercedes-Benz M-Class ML 350 4Matic                    0.0  2160.0     153.00
# Land Rover Freelander 2 TD4 HSE                        0.0  2160.0     115.00
# Hyundai Santro Xing (Non-AC)                           0.0  1086.0      62.10
# Hyundai Santro Xing (Non-AC)                           0.0  1086.0      62.10
# Mercedes-Benz M-Class ML 350 4Matic                    0.0  2160.0     153.00
# Hyundai Santro Xing GL                                 0.0  1086.0      62.00
# Volkswagen Polo GT TSI BSIV                            0.0  1197.0     103.25
# Volkswagen Polo GT TSI BSIV                            0.0  1197.0     103.25
# Mahindra Bolero Pik-Up FB 1.7T                         0.0  2160.0      70.00
# Hyundai Santro Xing GL                                 0.0  1086.0      62.00
# Mahindra Bolero Pik-Up CBC 1.7T                        0.0  2160.0      70.00
# Hyundai Santro Xing GL                                 0.0  1086.0      62.00
# Hyundai Santro Xing (Non-AC)                           0.0  1086.0      62.10
# Mercedes-Benz GLC 220d 4MATIC                          0.0  1950.0     153.00
#
#                                                    seats  Year_of_service
# name
# Tata Indica Vista Aura Safire Anniversary Edition    5.0               12
# Hyundai Santro Xing GL                               5.0               12
# Hyundai Santro Xing GL                               5.0               13
# Mercedes-Benz M-Class ML 350 4Matic                  5.0               10
# Land Rover Freelander 2 TD4 HSE                      5.0                8
# Hyundai Santro Xing (Non-AC)                         5.0               11
# Hyundai Santro Xing (Non-AC)                         5.0                8
# Mercedes-Benz M-Class ML 350 4Matic                  5.0               10
# Hyundai Santro Xing GL                               5.0               13
# Volkswagen Polo GT TSI BSIV                          5.0                7
# Volkswagen Polo GT TSI BSIV                          5.0                7
# Mahindra Bolero Pik-Up FB 1.7T                       2.0                1
# Hyundai Santro Xing GL                               5.0               11
# Mahindra Bolero Pik-Up CBC 1.7T                      2.0                2
# Hyundai Santro Xing GL                               5.0               10
# Hyundai Santro Xing (Non-AC)                         5.0               11
# Mercedes-Benz GLC 220d 4MATIC                        5.0                4

# %%
car1.loc[(car1['mileage'] <= 8),'mileage'] = round(lower_lim)

# %%
car1.loc[(car1['mileage'] <= 8)]
# Out:
#                                                    year  selling_price  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition  2009         135000
# Hyundai Santro Xing GL                             2009         120000
# Hyundai Santro Xing GL                             2008         105000
# Mercedes-Benz M-Class ML 350 4Matic                2011        1700000
# Land Rover Freelander 2 TD4 HSE                    2013        1650000
# Hyundai Santro Xing (Non-AC)                       2010         110000
# Hyundai Santro Xing (Non-AC)                       2013         184000
# Mercedes-Benz M-Class ML 350 4Matic                2011        1700000
# Hyundai Santro Xing GL                             2008         175000
# Volkswagen Polo GT TSI BSIV                        2014         574000
# Volkswagen Polo GT TSI BSIV                        2014         575000
# Mahindra Bolero Pik-Up FB 1.7T                     2020         679000
# Hyundai Santro Xing GL                             2010         150000
# Mahindra Bolero Pik-Up CBC 1.7T                    2019         722000
# Hyundai Santro Xing GL                             2011         150000
# Hyundai Santro Xing (Non-AC)                       2010         110000
# Mercedes-Benz GLC 220d 4MATIC                      2017        3300000
#
#                                                    km_driven    fuel  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition      28900  Petrol
# Hyundai Santro Xing GL                                 90000  Petrol
# Hyundai Santro Xing GL                                128000  Petrol
# Mercedes-Benz M-Class ML 350 4Matic                   110000  Diesel
# Land Rover Freelander 2 TD4 HSE                        64788  Diesel
# Hyundai Santro Xing (Non-AC)                           80000  Petrol
# Hyundai Santro Xing (Non-AC)                           15000  Petrol
# Mercedes-Benz M-Class ML 350 4Matic                   110000  Diesel
# Hyundai Santro Xing GL                                 40000  Petrol
# Volkswagen Polo GT TSI BSIV                            28080  Petrol
# Volkswagen Polo GT TSI BSIV                            28100  Petrol
# Mahindra Bolero Pik-Up FB 1.7T                          5000  Diesel
# Hyundai Santro Xing GL                                110000  Petrol
# Mahindra Bolero Pik-Up CBC 1.7T                        80000  Diesel
# Hyundai Santro Xing GL                                 40000  Petrol
# Hyundai Santro Xing (Non-AC)                           80000  Petrol
# Mercedes-Benz GLC 220d 4MATIC                          60000  Diesel
#
#                                                   seller_type transmission  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition  Individual       Manual
# Hyundai Santro Xing GL                             Individual       Manual
# Hyundai Santro Xing GL                             Individual       Manual
# Mercedes-Benz M-Class ML 350 4Matic                Individual    Automatic
# Land Rover Freelander 2 TD4 HSE                        Dealer    Automatic
# Hyundai Santro Xing (Non-AC)                       Individual       Manual
# Hyundai Santro Xing (Non-AC)                       Individual       Manual
# Mercedes-Benz M-Class ML 350 4Matic                Individual    Automatic
# Hyundai Santro Xing GL                             Individual       Manual
# Volkswagen Polo GT TSI BSIV                            Dealer    Automatic
# Volkswagen Polo GT TSI BSIV                            Dealer    Automatic
# Mahindra Bolero Pik-Up FB 1.7T                     Individual       Manual
# Hyundai Santro Xing GL                             Individual       Manual
# Mahindra Bolero Pik-Up CBC 1.7T                    Individual       Manual
# Hyundai Santro Xing GL                             Individual       Manual
# Hyundai Santro Xing (Non-AC)                       Individual       Manual
# Mercedes-Benz GLC 220d 4MATIC                          Dealer    Automatic
#
#                                                                   owner  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition          Second Owner
# Hyundai Santro Xing GL                                     Second Owner
# Hyundai Santro Xing GL                                      First Owner
# Mercedes-Benz M-Class ML 350 4Matic                         Third Owner
# Land Rover Freelander 2 TD4 HSE                             First Owner
# Hyundai Santro Xing (Non-AC)                               Second Owner
# Hyundai Santro Xing (Non-AC)                                First Owner
# Mercedes-Benz M-Class ML 350 4Matic                         Third Owner
# Hyundai Santro Xing GL                                      First Owner
# Volkswagen Polo GT TSI BSIV                                 First Owner
# Volkswagen Polo GT TSI BSIV                                 First Owner
# Mahindra Bolero Pik-Up FB 1.7T                              First Owner
# Hyundai Santro Xing GL                                      First Owner
# Mahindra Bolero Pik-Up CBC 1.7T                             First Owner
# Hyundai Santro Xing GL                             Fourth & Above Owner
# Hyundai Santro Xing (Non-AC)                               Second Owner
# Mercedes-Benz GLC 220d 4MATIC                               First Owner
#
#                                                    mileage  engine  max_power  \
# name
# Tata Indica Vista Aura Safire Anniversary Edition      8.0  1172.0      65.00
# Hyundai Santro Xing GL                                 8.0  1086.0      62.00
# Hyundai Santro Xing GL                                 8.0  1086.0      62.00
# Mercedes-Benz M-Class ML 350 4Matic                    8.0  2160.0     153.00
# Land Rover Freelander 2 TD4 HSE                        8.0  2160.0     115.00
# Hyundai Santro Xing (Non-AC)                           8.0  1086.0      62.10
# Hyundai Santro Xing (Non-AC)                           8.0  1086.0      62.10
# Mercedes-Benz M-Class ML 350 4Matic                    8.0  2160.0     153.00
# Hyundai Santro Xing GL                                 8.0  1086.0      62.00
# Volkswagen Polo GT TSI BSIV                            8.0  1197.0     103.25
# Volkswagen Polo GT TSI BSIV                            8.0  1197.0     103.25
# Mahindra Bolero Pik-Up FB 1.7T                         8.0  2160.0      70.00
# Hyundai Santro Xing GL                                 8.0  1086.0      62.00
# Mahindra Bolero Pik-Up CBC 1.7T                        8.0  2160.0      70.00
# Hyundai Santro Xing GL                                 8.0  1086.0      62.00
# Hyundai Santro Xing (Non-AC)                           8.0  1086.0      62.10
# Mercedes-Benz GLC 220d 4MATIC                          8.0  1950.0     153.00
#
#                                                    seats  Year_of_service
# name
# Tata Indica Vista Aura Safire Anniversary Edition    5.0               12
# Hyundai Santro Xing GL                               5.0               12
# Hyundai Santro Xing GL                               5.0               13
# Mercedes-Benz M-Class ML 350 4Matic                  5.0               10
# Land Rover Freelander 2 TD4 HSE                      5.0                8
# Hyundai Santro Xing (Non-AC)                         5.0               11
# Hyundai Santro Xing (Non-AC)                         5.0                8
# Mercedes-Benz M-Class ML 350 4Matic                  5.0               10
# Hyundai Santro Xing GL                               5.0               13
# Volkswagen Polo GT TSI BSIV                          5.0                7
# Volkswagen Polo GT TSI BSIV                          5.0                7
# Mahindra Bolero Pik-Up FB 1.7T                       2.0                1
# Hyundai Santro Xing GL                               5.0               11
# Mahindra Bolero Pik-Up CBC 1.7T                      2.0                2
# Hyundai Santro Xing GL                               5.0               10
# Hyundai Santro Xing (Non-AC)                         5.0               11
# Mercedes-Benz GLC 220d 4MATIC                        5.0                4

# %% [markdown]
# ## Boxplot of mileage after outlier treatment

# %%
sns.boxplot(x='mileage', data=car1)
# Out:
# <AxesSubplot:xlabel='mileage'>

# %% [markdown]
# ## Boxplot of mileage before outlier treatment

# %%
sns.boxplot(x='mileage', data=car_details)
# Out:
# <AxesSubplot:xlabel='mileage'>

# %%
fig,axes = plt.subplots(nrows=2, ncols=2, figsize=(15,6))
sns.boxplot(x='mileage',data=car1,ax=axes[0,0])
axes[0,0].set_xlabel('Boxplot of mileage after outlier treatment')
sns.boxplot(x='mileage',data=car_details,ax=axes[0,1])
axes[0,1].set_xlabel('Boxplot of mileage before outlier treatment')
sns.histplot(x='mileage',data=car1,kde=True,ax=axes[1,0])
axes[1,0].set_xlabel('Histogram of mileage after outlier treatment')
sns.histplot(x='mileage',data=car_details,kde=True,ax=axes[1,1])
axes[1,1].set_xlabel('Histogram of mileage before outlier treatment')
# Out:
# Text(0.5, 0, 'Histogram of mileage before outlier treatment')

# %% [markdown]
# ## For Mileage we can see that after outlier treatment the distribution became absolutely normally distributed

# %%
outliers.clear()
outlier_detection('km_driven')
# Out:
# {'count': 8128.0, 'mean': 69819.51082677166, 'std': 56550.554958218585, 'min': 1.0, '25%': 35000.0, '50%': 60000.0, '75%': 98000.0, 'max': 2360457.0}
# Q1 : 35000.0
# Q3 : 98000.0
# Inter quartile range is  63000.0
# The lower limit is  -59500
# The upper limit is  192500

# %%
min(outliers), max(outliers), len(outliers)
# Out:
# (193000, 2360457, 170)

# %% [markdown]
# ### Identifying the instances which are outliers for 'km_driven'

# %%
car1.loc[(car1['km_driven'] >= 192500) & (car1['km_driven'] <= 2360457)]
# Out:
#                                       year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire ZDi                2012         320000     193000  Diesel
# Mahindra Bolero DI DX 7 Seater        2007         210000     207890  Diesel
# Toyota Innova 2.5 G1 Diesel 8-seater  2005         250000     240000  Diesel
# Hyundai Verna XXi ABS (Petrol)        2009         340000     214000  Petrol
# Hyundai Verna CRDi SX                 2009         340000     214000  Diesel
# ...                                    ...            ...        ...     ...
# Chevrolet Enjoy TCDi LT 7 Seater      2014         275000     195000  Diesel
# Hyundai Verna 1.6 SX                  2012         450000     200000  Diesel
# Toyota Innova 2.5 V Diesel 7-seater   2010         425000     200000  Diesel
# Toyota Innova 2.5 E 7 STR             2009         550000     250000  Diesel
# Ford Figo Diesel Titanium             2012         260000     194000  Diesel
#
#                                      seller_type transmission         owner  \
# name
# Maruti Swift Dzire ZDi                Individual       Manual   First Owner
# Mahindra Bolero DI DX 7 Seater        Individual       Manual  Second Owner
# Toyota Innova 2.5 G1 Diesel 8-seater  Individual       Manual   Third Owner
# Hyundai Verna XXi ABS (Petrol)        Individual       Manual  Second Owner
# Hyundai Verna CRDi SX                 Individual       Manual  Second Owner
# ...                                          ...          ...           ...
# Chevrolet Enjoy TCDi LT 7 Seater      Individual       Manual   First Owner
# Hyundai Verna 1.6 SX                  Individual       Manual  Second Owner
# Toyota Innova 2.5 V Diesel 7-seater   Individual       Manual  Second Owner
# Toyota Innova 2.5 E 7 STR             Individual       Manual   First Owner
# Ford Figo Diesel Titanium             Individual       Manual   First Owner
#
#                                       mileage  engine  max_power  seats  \
# name
# Maruti Swift Dzire ZDi                  19.30  1248.0      73.90    5.0
# Mahindra Bolero DI DX 7 Seater          13.60  2160.0      63.00    7.0
# Toyota Innova 2.5 G1 Diesel 8-seater    12.80  2160.0     102.00    8.0
# Hyundai Verna XXi ABS (Petrol)          13.90  1599.0     103.20    5.0
# Hyundai Verna CRDi SX                   16.80  1493.0     110.00    5.0
# ...                                       ...     ...        ...    ...
# Chevrolet Enjoy TCDi LT 7 Seater        18.20  1248.0      73.80    7.0
# Hyundai Verna 1.6 SX                    22.32  1582.0     126.32    5.0
# Toyota Innova 2.5 V Diesel 7-seater     12.80  2160.0     102.00    7.0
# Toyota Innova 2.5 E 7 STR               12.80  2160.0     102.00    7.0
# Ford Figo Diesel Titanium               20.00  1399.0      68.00    5.0
#
#                                       Year_of_service
# name
# Maruti Swift Dzire ZDi                              9
# Mahindra Bolero DI DX 7 Seater                     14
# Toyota Innova 2.5 G1 Diesel 8-seater               16
# Hyundai Verna XXi ABS (Petrol)                     12
# Hyundai Verna CRDi SX                              12
# ...                                               ...
# Chevrolet Enjoy TCDi LT 7 Seater                    7
# Hyundai Verna 1.6 SX                                9
# Toyota Innova 2.5 V Diesel 7-seater                11
# Toyota Innova 2.5 E 7 STR                          12
# Ford Figo Diesel Titanium                           9
#
# [170 rows x 12 columns]

# %%
car1.loc[(car1['km_driven'] <= -59500)]
# Out:
# Empty DataFrame
# Columns: [year, selling_price, km_driven, fuel, seller_type, transmission, owner, mileage, engine, max_power, seats, Year_of_service]
# Index: []

# %%
car1.loc[(car1['km_driven'] >= 192500), 'km_driven'] = round(upper_lim)

# %% [markdown]
# ## Box plot of 'km_driven' before Treating outliers

# %%
sns.boxplot(x='km_driven', data=car_details)
# Out:
# <AxesSubplot:xlabel='km_driven'>

# %% [markdown]
# ## Box Plot of km_driven after treating outliers

# %%
sns.boxplot(x='km_driven', data=car1)
# Out:
# <AxesSubplot:xlabel='km_driven'>

# %%
fig,axes = plt.subplots(nrows=2, ncols=2, figsize=(15,6))
sns.boxplot(x='km_driven',data=car1,ax=axes[0,0])
axes[0,0].set_xlabel('Boxplot of km_driven after outlier treatment')
sns.boxplot(x='km_driven',data=car_details,ax=axes[0,1])
axes[0,1].set_xlabel('Boxplot of km_driven before outlier treatment')
sns.histplot(x='km_driven',data=car1,kde=True,ax=axes[1,0])
axes[1,0].set_xlabel('Histogram of km_driven after outlier treatment')
sns.histplot(x='km_driven',data=car_details,kde=True,ax=axes[1,1])
axes[1,1].set_xlabel('Histogram of km_driven before outlier treatment')
# Out:
# Text(0.5, 0, 'Histogram of km_driven before outlier treatment')

# %%
COR = car1.corr()

# %%
COR
# Out:
#                      year  selling_price  km_driven   mileage    engine  \
# year             1.000000       0.414092  -0.508028  0.332851  0.036331
# selling_price    0.414092       1.000000  -0.285015 -0.132050  0.465808
# km_driven       -0.508028      -0.285015   1.000000 -0.196632  0.230643
# mileage          0.332851      -0.132050  -0.196632  1.000000 -0.570672
# engine           0.036331       0.465808   0.230643 -0.570672  1.000000
# max_power        0.230146       0.635545  -0.021831 -0.402616  0.773844
# seats           -0.009144       0.041358   0.261552 -0.463404  0.586358
# Year_of_service -1.000000      -0.414092   0.508028 -0.332851 -0.036331
#
#                  max_power     seats  Year_of_service
# year              0.230146 -0.009144        -1.000000
# selling_price     0.635545  0.041358        -0.414092
# km_driven        -0.021831  0.261552         0.508028
# mileage          -0.402616 -0.463404        -0.332851
# engine            0.773844  0.586358        -0.036331
# max_power         1.000000  0.248845        -0.230146
# seats             0.248845  1.000000         0.009144
# Year_of_service  -0.230146  0.009144         1.000000

# %%
COR.selling_price.sort_values(ascending=False)
# Out:
# selling_price      1.000000
# max_power          0.635545
# engine             0.465808
# year               0.414092
# seats              0.041358
# mileage           -0.132050
# km_driven         -0.285015
# Year_of_service   -0.414092
# Name: selling_price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='max_power',y='selling_price',data=car_details,marker='o',color='red')
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='selling_price'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='max_power',y='selling_price',data=car1,marker='o',color='red')
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='selling_price'>

# %% [markdown]
# ### We can see that after outlier treatment the correlation between the 'max_power' and 'selling_price' has been reduced from 0.74 to 0.63 as a result of which the regression plot between them is not that much intuitive

# %%
car_details
# Out:
#                               year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire VDI        2014         450000     145500  Diesel
# Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# Honda City 2017-2020 EXi      2006         158000     140000  Petrol
# Hyundai i20 Sportz Diesel     2010         225000     127000  Diesel
# Maruti Swift VXI BSIII        2007         130000     120000  Petrol
# ...                            ...            ...        ...     ...
# Hyundai i20 Magna             2013         320000     110000  Petrol
# Hyundai Verna CRDi SX         2007         135000     119000  Diesel
# Maruti Swift Dzire ZDi        2009         382000     120000  Diesel
# Tata Indigo CR4               2013         290000      25000  Diesel
# Tata Indigo CR4               2013         290000      25000  Diesel
#
#                              seller_type transmission                 owner  \
# name
# Maruti Swift Dzire VDI        Individual       Manual           First Owner
# Skoda Rapid 1.5 TDI Ambition  Individual       Manual          Second Owner
# Honda City 2017-2020 EXi      Individual       Manual           Third Owner
# Hyundai i20 Sportz Diesel     Individual       Manual           First Owner
# Maruti Swift VXI BSIII        Individual       Manual           First Owner
# ...                                  ...          ...                   ...
# Hyundai i20 Magna             Individual       Manual           First Owner
# Hyundai Verna CRDi SX         Individual       Manual  Fourth & Above Owner
# Maruti Swift Dzire ZDi        Individual       Manual           First Owner
# Tata Indigo CR4               Individual       Manual           First Owner
# Tata Indigo CR4               Individual       Manual           First Owner
#
#                               mileage  engine  max_power  seats  \
# name
# Maruti Swift Dzire VDI          23.40  1248.0      74.00    5.0
# Skoda Rapid 1.5 TDI Ambition    21.14  1498.0     103.52    5.0
# Honda City 2017-2020 EXi        17.70  1497.0      78.00    5.0
# Hyundai i20 Sportz Diesel       23.00  1396.0      90.00    5.0
# Maruti Swift VXI BSIII          16.10  1298.0      88.20    5.0
# ...                               ...     ...        ...    ...
# Hyundai i20 Magna               18.50  1197.0      82.85    5.0
# Hyundai Verna CRDi SX           16.80  1493.0     110.00    5.0
# Maruti Swift Dzire ZDi          19.30  1248.0      73.90    5.0
# Tata Indigo CR4                 23.57  1396.0      70.00    5.0
# Tata Indigo CR4                 23.57  1396.0      70.00    5.0
#
#                               Year_of_service
# name
# Maruti Swift Dzire VDI                      7
# Skoda Rapid 1.5 TDI Ambition                7
# Honda City 2017-2020 EXi                   15
# Hyundai i20 Sportz Diesel                  11
# Maruti Swift VXI BSIII                     14
# ...                                       ...
# Hyundai i20 Magna                           8
# Hyundai Verna CRDi SX                      14
# Maruti Swift Dzire ZDi                     12
# Tata Indigo CR4                             8
# Tata Indigo CR4                             8
#
# [8128 rows x 12 columns]

# %%
car_details[car_details['Year_of_service']==38]
# Out:
#                            year  selling_price  km_driven    fuel seller_type  \
# name
# Mahindra Willys CJ 3B 4X4  1983         300000      10000  Diesel  Individual
#
#                           transmission        owner  mileage  engine  \
# name
# Mahindra Willys CJ 3B 4X4       Manual  Third Owner      NaN     NaN
#
#                            max_power  seats  Year_of_service
# name
# Mahindra Willys CJ 3B 4X4        NaN    NaN               38

# %% [markdown]
# ## 'Year_of_service' is the column made for EDA and lloking into the selling price variation for old car

# %%
car_details = car_details.drop('Year_of_service',axis=1)

# %%
car_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8128 entries, Maruti Swift Dzire VDI to Tata Indigo CR4
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8128 non-null   int64
#  1   selling_price  8128 non-null   int64
#  2   km_driven      8128 non-null   int64
#  3   fuel           8128 non-null   object
#  4   seller_type    8128 non-null   object
#  5   transmission   8128 non-null   object
#  6   owner          8128 non-null   object
#  7   mileage        7907 non-null   float64
#  8   engine         7907 non-null   float64
#  9   max_power      7912 non-null   float64
#  10  seats          7907 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 891.0+ KB

# %%
car_details.head()
# Out:
#                               year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire VDI        2014         450000     145500  Diesel
# Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# Honda City 2017-2020 EXi      2006         158000     140000  Petrol
# Hyundai i20 Sportz Diesel     2010         225000     127000  Diesel
# Maruti Swift VXI BSIII        2007         130000     120000  Petrol
#
#                              seller_type transmission         owner  mileage  \
# name
# Maruti Swift Dzire VDI        Individual       Manual   First Owner    23.40
# Skoda Rapid 1.5 TDI Ambition  Individual       Manual  Second Owner    21.14
# Honda City 2017-2020 EXi      Individual       Manual   Third Owner    17.70
# Hyundai i20 Sportz Diesel     Individual       Manual   First Owner    23.00
# Maruti Swift VXI BSIII        Individual       Manual   First Owner    16.10
#
#                               engine  max_power  seats
# name
# Maruti Swift Dzire VDI        1248.0      74.00    5.0
# Skoda Rapid 1.5 TDI Ambition  1498.0     103.52    5.0
# Honda City 2017-2020 EXi      1497.0      78.00    5.0
# Hyundai i20 Sportz Diesel     1396.0      90.00    5.0
# Maruti Swift VXI BSIII        1298.0      88.20    5.0

# %% [markdown]
# ## Dropping all the null values

# %%
car_details = car_details.dropna()

# %%
car_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7906 entries, Maruti Swift Dzire VDI to Tata Indigo CR4
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7906 non-null   int64
#  1   selling_price  7906 non-null   int64
#  2   km_driven      7906 non-null   int64
#  3   fuel           7906 non-null   object
#  4   seller_type    7906 non-null   object
#  5   transmission   7906 non-null   object
#  6   owner          7906 non-null   object
#  7   mileage        7906 non-null   float64
#  8   engine         7906 non-null   float64
#  9   max_power      7906 non-null   float64
#  10  seats          7906 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 741.2+ KB

# %%
car_details.head(10)
# Out:
#                                       year  selling_price  km_driven    fuel  \
# name
# Maruti Swift Dzire VDI                2014         450000     145500  Diesel
# Skoda Rapid 1.5 TDI Ambition          2014         370000     120000  Diesel
# Honda City 2017-2020 EXi              2006         158000     140000  Petrol
# Hyundai i20 Sportz Diesel             2010         225000     127000  Diesel
# Maruti Swift VXI BSIII                2007         130000     120000  Petrol
# Hyundai Xcent 1.2 VTVT E Plus         2017         440000      45000  Petrol
# Maruti Wagon R LXI DUO BSIII          2007          96000     175000     LPG
# Maruti 800 DX BSII                    2001          45000       5000  Petrol
# Toyota Etios VXD                      2011         350000      90000  Diesel
# Ford Figo Diesel Celebration Edition  2013         200000     169000  Diesel
#
#                                      seller_type transmission         owner  \
# name
# Maruti Swift Dzire VDI                Individual       Manual   First Owner
# Skoda Rapid 1.5 TDI Ambition          Individual       Manual  Second Owner
# Honda City 2017-2020 EXi              Individual       Manual   Third Owner
# Hyundai i20 Sportz Diesel             Individual       Manual   First Owner
# Maruti Swift VXI BSIII                Individual       Manual   First Owner
# Hyundai Xcent 1.2 VTVT E Plus         Individual       Manual   First Owner
# Maruti Wagon R LXI DUO BSIII          Individual       Manual   First Owner
# Maruti 800 DX BSII                    Individual       Manual  Second Owner
# Toyota Etios VXD                      Individual       Manual   First Owner
# Ford Figo Diesel Celebration Edition  Individual       Manual   First Owner
#
#                                       mileage  engine  max_power  seats
# name
# Maruti Swift Dzire VDI                  23.40  1248.0      74.00    5.0
# Skoda Rapid 1.5 TDI Ambition            21.14  1498.0     103.52    5.0
# Honda City 2017-2020 EXi                17.70  1497.0      78.00    5.0
# Hyundai i20 Sportz Diesel               23.00  1396.0      90.00    5.0
# Maruti Swift VXI BSIII                  16.10  1298.0      88.20    5.0
# Hyundai Xcent 1.2 VTVT E Plus           20.14  1197.0      81.86    5.0
# Maruti Wagon R LXI DUO BSIII            17.30  1061.0      57.50    5.0
# Maruti 800 DX BSII                      16.10   796.0      37.00    4.0
# Toyota Etios VXD                        23.59  1364.0      67.10    5.0
# Ford Figo Diesel Celebration Edition    20.00  1399.0      68.10    5.0

# %%
# Checking the information and statistical description of the dataset made after the outlier treatment
car1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8128 entries, Maruti Swift Dzire VDI to Tata Indigo CR4
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             8128 non-null   int64
#  1   selling_price    8128 non-null   int64
#  2   km_driven        8128 non-null   int64
#  3   fuel             8128 non-null   object
#  4   seller_type      8128 non-null   object
#  5   transmission     8128 non-null   object
#  6   owner            8128 non-null   object
#  7   mileage          7907 non-null   float64
#  8   engine           7907 non-null   float64
#  9   max_power        7912 non-null   float64
#  10  seats            7907 non-null   float64
#  11  Year_of_service  8128 non-null   int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 954.5+ KB

# %%
car1.describe()
# Out:
#               year  selling_price      km_driven      mileage       engine  \
# count  8128.000000   8.128000e+03    8128.000000  7907.000000  7907.000000
# mean   2013.804011   6.382718e+05   68311.382013    19.433062  1415.506007
# std       4.044249   8.062534e+05   43569.154403     3.960003   411.868607
# min    1983.000000   2.999900e+04       1.000000     8.000000   624.000000
# 25%    2011.000000   2.549990e+05   35000.000000    16.780000  1197.000000
# 50%    2015.000000   4.500000e+05   60000.000000    19.300000  1248.000000
# 75%    2017.000000   6.750000e+05   98000.000000    22.320000  1582.000000
# max    2020.000000   1.000000e+07  192500.000000    31.000000  2160.000000
#
#          max_power        seats  Year_of_service
# count  7912.000000  7907.000000      8128.000000
# mean     89.156532     5.416719         7.195989
# std      29.211694     0.959588         4.044249
# min      17.000000     2.000000         1.000000
# 25%      68.050000     5.000000         4.000000
# 50%      82.000000     5.000000         6.000000
# 75%     102.000000     5.000000        10.000000
# max     153.000000    14.000000        38.000000
